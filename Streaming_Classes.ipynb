# %% [markdown]
# <a href="https://colab.research.google.com/github/Spectre-prog/Spectre-prog/blob/main/Streaming_Classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
print('Hello world')
# Out:
# Hello world

# %%
print('First Line \n Second Line \n Third Line')
# Out:
# First Line
#  Second Line
#  Third Line

# %%
print 4
# Out:
#   File "<ipython-input-5-f447ae0d8f3a>", line 1
#     print 4
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print(4 + 4)
# Out:
# 8

# %%
4+4+4
# Out:
# 12

# %%
4*4-4
# Out:
# 12

# %%
 print(type(12.0))
# Out:
# <class 'float'>

# %%
print(type(None))
# Out:
# <class 'NoneType'>

# %%
integer=12.55555
print(integer)
# Out:
# 12.55555

# %%
import math
print(math.sqrt (16))
# Out:
# 4.0

# %%
import math
print(math.sin(30))
# Out:
# -0.9880316240928618

# %%
import math
print(math.sin(40))
# Out:
# 0.7451131604793488

# %% [markdown]
# Note that in python, the comb is combination

# %%
print(math.comb(8,3))
# Out:
# 56

# %%
help(math.ceil)
# Out:
# Help on built-in function ceil in module math:
#
# ceil(x, /)
#     Return the ceiling of x as an Integral.
#
#     This is the smallest integer >= x.

# %%
def draw_cat_face():
    cat_face = r'''
      /\_/\
     ( o.o )
      > ^ <
    '''
    print(cat_face)

draw_cat_face()
# Out:
#       /\_/\
#      ( o.o )
#       > ^ <

# %%
list = ('-5', '-2', '7', '12','19', '27', '36')
print(list[0])
# Out:
# -5

# %%
import random

def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 9)

def check_winner(board):
    for row in board:
        if row.count(row[0]) == 3 and row[0] != " ":
            return True

    for col in range(3):
        if board[0][col] == board[1][col] == board[2][col] and board[0][col] != " ":
            return True

    if board[0][0] == board[1][1] == board[2][2] and board[0][0] != " ":
        return True

    if board[0][2] == board[1][1] == board[2][0] and board[0][2] != " ":
        return True

    return False

def is_board_full(board):
    return all(cell != " " for row in board for cell in row)

def computer_move(board):
    empty_cells = [(r, c) for r in range(3) for c in range(3) if board[r][c] == " "]
    return random.choice(empty_cells)

def main():
    board = [[" " for _ in range(3)] for _ in range(3)]
    current_player = "X"  # Computer starts as X

    while True:
        print_board(board)

        if current_player == "X":
            # Computer's turn
            row, col = computer_move(board)
            board[row][col] = current_player
            print(f"Computer placed X at position {row * 3 + col}")
        else:
            # Player's turn
            move = int(input("Enter a number (0-8) to place O: "))

            if move < 0 or move > 8:
                print("Invalid move. Please enter a number between 0 and 8.")
                continue

            # Determine row and column based on the input number
            row = move // 3
            col = move % 3

            if board[row][col] != " ":
                print("Cell already taken. Try again.")
                continue

            board[row][col] = current_player

        if check_winner(board):
            print_board(board)
            print(f"Player {current_player} wins!")
            break

        if is_board_full(board):
            print_board(board)
            print("It's a tie!")
            break

        current_player = "O" if current_player == "X" else "X"

if __name__ == "__main__":
    main()
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Computer placed X at position 2
#   |   | X
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Enter a number (0-8) to place O: 5
#   |   | X
# ---------
#   |   | O
# ---------
#   |   |
# ---------
# Computer placed X at position 6
#   |   | X
# ---------
#   |   | O
# ---------
# X |   |
# ---------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-304293d8d104> in <cell line: 74>()
#      73
#      74 if __name__ == "__main__":
# ---> 75     main()
#
# <ipython-input-7-304293d8d104> in main()
#      44         else:
#      45             # Player's turn
# ---> 46             move = int(input("Enter a number (0-8) to place O: "))
#      47
#      48             if move < 0 or move > 8:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %%
menu = ['Starters', ['Salads', ['Caeser'], 'Caaprese']]
caeser = menu[1][0]
print(caeser)
# Out:
# Salads

# %%
menu = ['Starters', ['Salads', ['Caeser', 'Soup'], 'Caaprese']]
caeser = menu[1][0]
print(caeser)
# Out:
# Salads

# %% [markdown]
# https://www.w3schools.com/python/python_ref_list.asp

# %%
menu = ['Starters', ['Salads', ['Caeser', 'Soup'], 'Caaprese']]
menu.append ('Dessert')
print(menu)
# Out:
# ['Starters', ['Salads', ['Caeser', 'Soup'], 'Caaprese'], 'Dessert']

# %%
menu = ['Starters', ['Salads', ['Caeser', 'Soup'], 'Caaprese']]
men.append ('Dessert')
print(menu)
menu.insert(0, 'freshman')

# %%
fruits = []

fruits.append("Apple")
fruits.append("Banana")
fruits.append("Cherry")
fruits.append("Date")
print("After appending:", fruits)
fruits.sort()
print("After sorting:", fruits)
fruits.reverse()
print("After reversing:", fruits)
popped_fruit = fruits.pop()  # Removes the last item
print("Popped fruit:", popped_fruit)
print("After popping:", fruits)
fruits.remove("Banana")
print("After removing Banana:", fruits)
count_apple = fruits.count("Apple")
print("Count of Apple:", count_apple)
fruits_copy = fruits.copy()
print("Copied list:", fruits_copy)
fruits.insert(1, "Cucumber")
print("After inserting Cucumber at index 1:", fruits)
fruits.clear()
print("After clearing:", fruits)
fruits.extend(["Fig", "Grape", "Honeydew", "Agbalumo"])
print("After extending with new fruits:", fruits)
# Out:
# After appending: ['Apple', 'Banana', 'Cherry', 'Date']
# After sorting: ['Apple', 'Banana', 'Cherry', 'Date']
# After reversing: ['Date', 'Cherry', 'Banana', 'Apple']
# Popped fruit: Apple
# After popping: ['Date', 'Cherry', 'Banana']
# After removing Banana: ['Date', 'Cherry']
# Count of Apple: 0
# Copied list: ['Date', 'Cherry']
# After inserting Cucumber at index 1: ['Date', 'Cucumber', 'Cherry']
# After clearing: []
# After extending with new fruits: ['Fig', 'Grape', 'HoneydewAgbalumo']

# %%
print(range(10, 20))
# Out:
# range(10, 20)

# %%
print(list(range(10, 20)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-2ae053a1c994> in <cell line: 1>()
# ----> 1 print(list(range(10, 20)))
#
# TypeError: 'tuple' object is not callable

# %%
list_names = file.png
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6a7bf7d59263> in <cell line: 1>()
# ----> 1 list_names = file.png
#
# NameError: name 'file' is not defined

# %%
file = 'filename.png'
file_without_extension = file[:-4]  # Remove the last four characters ('.png')
print(file_without_extension)
# Out:
# filename

# %%
a,b,c, *xyz = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print(a)
print(b)
print(xyz)
# Out:
# 1
# 2
# [4, 5, 6, 7, 8, 9]

# %%
file = 'filename.png'
file_without_extension = file[:-4]  # Remove the last four characters ('.png')
print(file_without_extension)
# Out:
# filename

# %%
profile = {
    'name': 'Alice',
    'age':  30,
    'hobbies': ['reading', 'cycling']
}
profile['height'] = 160
print(profile)
del profile['age']
print(profile)
# Out:
# {'name': 'Alice', 'age': 30, 'hobbies': ['reading', 'cycling'], 'height': 160}
# {'name': 'Alice', 'hobbies': ['reading', 'cycling'], 'height': 160}

# %%
profile = {
    'name': 'Alice',
    'age':  30,
    'hobbies': ['reading', 'cycling'],
    'name1': 'Alice'
}
profile['height'] = 160
print(profile)
del profile['age']
print(profile)
# Out:
# {'name': 'Alice', 'age': 30, 'hobbies': ['reading', 'cycling'], 'height': 160}
# {'name': 'Alice', 'hobbies': ['reading', 'cycling'], 'height': 160}

# %%
import pandas as pd
import numpy as np

headers_data = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]


df = pd.read_csv('dataset_1.data',names = headers_data)

print(df)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.head (15)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
df.tail (10)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 195         -1                74  volvo       gas        std         four
# 196         -2               103  volvo       gas        std         four
# 197         -1                74  volvo       gas        std         four
# 198         -2               103  volvo       gas      turbo         four
# 199         -1                74  volvo       gas      turbo         four
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 195      wagon          rwd           front       104.3  ...          141
# ...

# %%
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.describe(include = "all")
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           205        205          205             205  205.000000  ...
# ...

# %%
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.to csv
